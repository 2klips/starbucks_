# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import folium
from pymongo import MongoClient

# !python -m pip install "pymongo[srv]"==3.11
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
def starbucks_stores(region_xpath):
    driver = webdriver.Chrome()
    url = 'https://www.starbucks.co.kr:7643/store/store_map.do?disp=locale'

    driver.get(url)
    time.sleep(3)

    # 지역 선택
    driver.find_element('xpath', region_xpath).click()
    time.sleep(2)

    # 전체 선택
    driver.find_element('xpath', '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[2]/div[3]/div/div/div[1]/ul/li[1]/a').click()
    time.sleep(3)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    stores = soup.select('li.quickResultLstCon')
    data = []

    for store in stores:
        name = store.select('strong')[0].text
        lat = store['data-lat']
        lng = store['data-long']
        address = str(store.select('p.result_details')[0]).split('<br/>')[0].split('>')[1]
        tel = str(store.select('p.result_details')[0]).split('<br/>')[1].split('<')[0]

        data.append([name, lat, lng, address, tel])

    columns = ['매장명', '위도', '경도', '주소', '전화번호']
    df = pd.DataFrame(data, columns=columns)
    
    driver.quit()
    
    return df

# %%
def starbucks_sejung_stores(region_xpath):
    driver = webdriver.Chrome()
    url = 'https://www.starbucks.co.kr:7643/store/store_map.do?disp=locale'

    driver.get(url)
    time.sleep(3)

    driver.find_element('xpath', region_xpath).click()
    time.sleep(2)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    stores = soup.select('li.quickResultLstCon')
    data = []

    for store in stores:
        name = store.select('strong')[0].text
        lat = store['data-lat']
        lng = store['data-long']
        address = str(store.select('p.result_details')[0]).split('<br/>')[0].split('>')[1]
        tel = str(store.select('p.result_details')[0]).split('<br/>')[1].split('<')[0]

        data.append([name, lat, lng, address, tel])

    columns = ['매장명', '위도', '경도', '주소', '전화번호']
    df = pd.DataFrame(data, columns=columns)
    
    driver.quit()
    
    return df

# %%
seoul_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[1]/a'
gyunggi_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[2]/a'
gwangju_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[3]/a'
deagu_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[4]/a'
deajun_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[5]/a'
busan_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[6]/a'
ulsan_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[7]/a'
incheon_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[8]/a'
gwangwon_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[9]/a'
gyungnam_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[10]/a'
gyungbook_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[11]/a'
junnam_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[12]/a'
junbook_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[13]/a'
choongnam_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[14]/a'
choongbook_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[15]/a'
jeju_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[16]/a'
sejung_xpath = '/html/body/div[4]/div[7]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[17]/a'


seoul_df = starbucks_stores(seoul_xpath)
gyunggi_df = starbucks_stores(gyunggi_xpath)
gwangju_df = starbucks_stores(gwangju_xpath)
deagu_df = starbucks_stores(deagu_xpath)
deajun_df = starbucks_stores(deajun_xpath)
busan_df = starbucks_stores(busan_xpath)
ulsan_df = starbucks_stores(ulsan_xpath)
incheon_df = starbucks_stores(incheon_xpath)
gwangwon_df = starbucks_stores(gwangwon_xpath)
gyungnam_df = starbucks_stores(gyungnam_xpath)
gyungbook_df = starbucks_stores(gyungbook_xpath)
junnam_df = starbucks_stores(junnam_xpath)
junbook_df = starbucks_stores(junbook_xpath)
choongnam_df = starbucks_stores(choongnam_xpath)
choongbook_df = starbucks_stores(choongbook_xpath)
jeju_df = starbucks_stores(jeju_xpath)
sejung_df = starbucks_sejung_stores(sejung_xpath)

# %%
def typechange(df):
    df = df.astype({'위도':'float', '경도':'float'})
    return df

# %%
seoul_df = typechange(seoul_df)
gyunggi_df = typechange(gyunggi_df)
gwangju_df = typechange(gwangju_df)
deagu_df = typechange(deagu_df)
deajun_df = typechange(deajun_df)
busan_df = typechange(busan_df)
ulsan_df = typechange(ulsan_df)
incheon_df = typechange(incheon_df)
gwangwon_df = typechange(gwangwon_df)
gyungnam_df = typechange(gyungnam_df)
gyungbook_df = typechange(gyungbook_df)
junnam_df = typechange(junnam_df)
junbook_df = typechange(junbook_df)
choongnam_df = typechange(choongnam_df)
choongbook_df = typechange(choongbook_df)
jeju_df = typechange(jeju_df)
sejung_df = typechange(sejung_df)

# %%
url = 'mongodb+srv://axz1420:dlgusdn113!@store.jvq4o15.mongodb.net/?retryWrites=true&w=majority&appName=store'
client = MongoClient(url)
database = client['starbucks']

# %%
dataframes = [
    seoul_df, gyunggi_df, gwangju_df, deagu_df, deajun_df, busan_df,
    ulsan_df, incheon_df, gwangwon_df, gyungnam_df, gyungbook_df,
    junnam_df, junbook_df, choongnam_df, choongbook_df, jeju_df, sejung_df
]

dataframes_dict = {
    'seoul': seoul_df, 'gyunggi': gyunggi_df, 'gwangju': gwangju_df, 'deagu': deagu_df, 'deajun': deajun_df, 'busan': busan_df,
    'ulsan': ulsan_df, 'incheon': incheon_df, 'gwangwon': gwangwon_df, 'gyungnam': gyungnam_df, 'gyungbook': gyungbook_df,
    'junnam': junnam_df, 'junbook': junbook_df, 'choongnam': choongnam_df, 'choongbook': choongbook_df, 'jeju': jeju_df, 'sejung': sejung_df
}

# %%
for name, df in dataframes_dict.items():
    records = df.to_dict(orient='records')  
    collection = database[name + '_stores']  
    collection.insert_many(records)

# %%
for df in dataframes:
    records = df.to_dict(orient='records')
    collection.insert_many(records)

# %%
url = 'mongodb+srv://axz1420:dlgusdn113!@store.jvq4o15.mongodb.net/?retryWrites=true&w=majority&appName=store'
client = MongoClient(url)
database = client['starbucks']

database_stores = database.list_collection_names()

collection = database['seoul_stores']
seoul_stores = collection.find()
seoul_stores = pd.DataFrame(seoul_stores)

collection = database['gyunggi_stores']
gyunggi_stores = collection.find()
gyunggi_stores = pd.DataFrame(gyunggi_stores)

collection = database['gwangju_stores']
gwangju_stores = collection.find()
gwangju_stores = pd.DataFrame(gwangju_stores)

collection = database['deagu_stores']
deagu_stores = collection.find()
deagu_stores = pd.DataFrame(deagu_stores)

collection = database['deajun_stores']
deajun_stores = collection.find()
deajun_stores = pd.DataFrame(deajun_stores)

collection = database['busan_stores']
busan_stores = collection.find()
busan_stores = pd.DataFrame(busan_stores)

collection = database['ulsan_stores']
ulsan_stores = collection.find()
ulsan_stores = pd.DataFrame(ulsan_stores)

collection = database['incheon_stores']
incheon_stores = collection.find()
incheon_stores = pd.DataFrame(incheon_stores)

collection = database['gwangwon_stores']
gwangwon_stores = collection.find()
gwangwon_stores = pd.DataFrame(gwangwon_stores)

collection = database['gyungnam_stores']
gyungnam_stores = collection.find()
gyungnam_stores = pd.DataFrame(gyungnam_stores)

collection = database['gyungbook_stores']
gyungbook_stores = collection.find()
gyungbook_stores = pd.DataFrame(gyungbook_stores)

collection = database['junnam_stores']
junnam_stores = collection.find()
junnam_stores = pd.DataFrame(junnam_stores)

collection = database['junbook_stores']
junbook_stores = collection.find()
junbook_stores = pd.DataFrame(junbook_stores)

collection = database['choongnam_stores']
choongnam_stores = collection.find()
choongnam_stores = pd.DataFrame(choongnam_stores)

collection = database['choongbook_stores']
choongbook_stores = collection.find()
choongbook_stores = pd.DataFrame(choongbook_stores)

collection = database['jeju_stores']
jeju_stores = collection.find()
jeju_stores = pd.DataFrame(jeju_stores)

collection = database['sejung_stores']
sejung_stores = collection.find()
sejung_stores = pd.DataFrame(sejung_stores)

collection = database['stores']
stores = collection.find()
stores = pd.DataFrame(stores)

# %%
def show_map(df):
    map  = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=12)
    for data in range(len(df)): 
        popup = folium.Popup(f"{df['매장명'][data]+'점'}</br>{df['주소'][data]}</br>{df['전화번호'][data]}", 
                            max_width=200)
        folium.Marker([df['위도'][data], df['경도'][data]], popup=popup).add_to(map)
    
    return map

# %%
# 'stores'
# 'choongbook_stores'
# 'choongnam_stores'
# 'junbook_stores'
# 'junnam_stores'
# 'incheon_stores'
# 'gyungnam_stores'
# 'busan_stores'
# 'deagu_stores'
# 'gyungbook_stores'
# 'gwangwon_stores'
# 'deajun_stores'
# 'ulsan_stores'
# 'gwangju_stores'
# 'gyunggi_stores'
# 'sejung_stores'
# 'jeju_stores'
# 'seoul_stores'

show_map(incheon_stores)
